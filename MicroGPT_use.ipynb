# %%
#https://karpathy.github.io/2026/02/12/microgpt/?s=08

# %%
#check the file in the models folder
import os
os.path.exists('/home/german1/ai-learning/models/llm/train.py')  # should print True
# Out:
# True

# %%
#run the file with the correct path of the file
# %run /home/german1/ai-learning/models/llm/train.py
# Out:
# num docs: 32033
# vocab size: 27
# num params: 4192
# step 1000 / 1000 | loss 2.6497
# --- inference (new, hallucinated names) ---
# sample  1: kamon
# sample  2: ann
# sample  3: karai
# sample  4: jaire
# sample  5: vialan
# sample  6: karia
# sample  7: yeran
# sample  8: anna
# sample  9: areli
# sample 10: kaina
# sample 11: konna
# sample 12: keylen
# sample 13: liole
# sample 14: alerin
# sample 15: earan
# sample 16: lenne
# sample 17: kana
# sample 18: lara
# sample 19: alela
# sample 20: anton
