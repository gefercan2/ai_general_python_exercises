# %%
import psutil
import os
from pathlib import Path

ram = psutil.virtual_memory()
print(f"Total RAM   : {ram.total / 1e9:.1f} GB")
print(f"Available   : {ram.available / 1e9:.1f} GB")

if ram.available < 3e9:
    print("Warning: less than 3GB free — model may crash. Close other apps first.")
else:
    print("RAM looks good.")

# %%
# --- Dependencies ---
import docling
import pypdf
from PIL import Image
import docx
print("All docling dependencies loaded ok")

# %%
# --- Pipeline Setup (CPU-safe mode) ---
from docling.datamodel.pipeline_options import PdfPipelineOptions
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.datamodel.base_models import InputFormat

pipeline_options = PdfPipelineOptions()
pipeline_options.accelerator_options.cuda_use_flash_attention2 = False

converter = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
    }
)
print("Pipeline ready.")

# %%
# --- PDF List — add or remove files here ---
pdf_files = [
 
   "/home/german1/Downloads/literatura_Cervantes_La Galatea.pdf", 
   "/home/german1/Downloads/literatura_cervantes_eng_quixote_book0530.pdf", 
    

    # replace with real path
]

# --- Process each PDF ---
for pdf_path in pdf_files:
    pdf_path = Path(pdf_path)

    if not pdf_path.exists():
        print(f"\n⚠️  Skipping (file not found): {pdf_path}")
        continue

    print(f"\n📄 Converting: {pdf_path.name} ...")

    try:
        result = converter.convert(str(pdf_path))
        markdown_text = result.document.export_to_markdown()

        # Build output path: same folder, same name, .md extension
        output_path = pdf_path.with_suffix(".md")

        with open(output_path, "w", encoding="utf-8") as f:
            f.write(markdown_text)

        print(f"✅ Saved: {output_path}")

    except Exception as e:
        print(f"❌ Failed to convert {pdf_path.name}: {e}")

print("\nAll done!")

# %%
         "/home/german1/Downloads/literatura_HOMER_6130-pdf.pdf", 
    "/home/german1/Downloads/literatura_Matriz musical de Jorge Eduardo Eielson & Selección de poesía.pdf", 
    "/home/german1/Downloads/literatura_EIELSON_151973.pdf", 
     "/home/german1/Downloads/literatura_El cuerpo de Giulia-no de Jorge Eduardo Eielson_MINARDI, Giovanna.pdf",
    "/home/german1/Downloads/literatura_EIELSONJORGE--NOCHE-OSCURA-DEL-CUERPO.pdf", 
    "/home/german1/Downloads/Cosmology and Theology (Stanford Encyclopedia of Philosophy).pdf",
    "/home/german1/Downloads/Pascal’s Wager (Stanford Encyclopedia of Philosophy).pdf",
    "/home/german1/Downloads/Descartes’ Epistemology (Stanford Encyclopedia of Philosophy).pdf",
    "/home/german1/Downloads/Karl Popper (Stanford Encyclopedia of Philosophy).pdf",
    "/home/german1/Downloads/Structured Propositions (Stanford Encyclopedia of Philosophy).pdf",
    "/home/german1/Downloads/Leibniz’s Philosophy of Mind (Stanford Encyclopedia of Philosophy).pdf",
    "/home/german1/Downloads/Prisoner’s Dilemma (Stanford Encyclopedia of Philosophy).pdf",
    "/home/german1/Downloads/Nietzsche’s Life and Works (Stanford Encyclopedia of Philosophy).pdf",
    "/home/german1/Downloads/Friedrich Nietzsche (Stanford Encyclopedia of Philosophy).pdf",
    "/home/german1/Downloads/Game Theory (Stanford Encyclopedia of Philosophy).pdf",
